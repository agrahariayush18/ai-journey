# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
age = input("Enter your age: ")
print(age)
# Out:
# 10

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
num = int(input("Enter your number: "))
if num>0:
    print("Number is positive")
elif num<0:
    print("Number is negative")
else:
    print("Number is zero")
# Out:
# Number is negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
num1 = int(input("Enter your number: "))
num2 = int(input("Enter your number: "))
num3 = int(input("Enter your number: "))

if num1>num2 and num1>num3:
    print("Number 1 is greater")
elif num2>num1 and num2>num3:
    print("Number 2 is greater")
else:
    print("Number 3 is greater")

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def factorial(num):
    if num == 0 or num == 1:
        return 1
    else:
        return num * factorial(num-1)

num=int(input("enter the number"))
print("the factorial of",num,"is",factorial(num))
# Out:
# the factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# 1. Create variables of different data types
a = 10          # Integer (int)
b = 10.5        # Float (float - has a decimal)
c = "Hello"     # String (str - text in quotes)
d = True        # Boolean (bool - True or False)

# 2. Print their values and types
print("Value:", a, "| Type:", type(a))
print("Value:", b, "| Type:", type(b))
print("Value:", c, "| Type:", type(c))
print("Value:", d, "| Type:", type(d))
# Out:
# Value: 10 | Type: <class 'int'>
# Value: 10.5 | Type: <class 'float'>
# Value: Hello | Type: <class 'str'>
# Value: True | Type: <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a =10 
b = 20

a,b = b,a
print(a)
print(b)
# Out:
# 20
# 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
# 1. Ask the user to enter a temperature in Celsius
celsius = float(input("Enter temperature in Celsius: "))

# 2. Calculate the Fahrenheit equivalent
fahrenheit = (celsius * 9/5) + 32

# 3. Print the result
print(celsius, "°C is equal to", fahrenheit, "°F")
# Out:
# 0.0 °C is equal to 32.0 °F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "Hello"
str2 = "World"

print(str1 + str2)
# Out:
# HelloWorld

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
a = 10
b = "Hello"

print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 10
b = 20

sum = a+b 
sub = a-b
mul = a*b 
div = a/b

print(sum)
print(sub)
print(mul)
print(div)
# Out:
# 30
# -10
# 200
# 0.5

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
# Create two variables to compare
a = 15
b = 10

print("Variables: a =", a, ", b =", b)
print("-" * 30)

# 1. Equal to (==)
print("a == b (Equal to):", a == b)

# 2. Not equal to (!=)
print("a != b (Not equal to):", a != b)

# 3. Greater than (>)
print("a > b  (Greater than):", a > b)

# 4. Less than (<)
print("a < b  (Less than):", a < b)
# Out:
# Variables: a = 15 , b = 10
# ------------------------------
# a == b (Equal to): False
# a != b (Not equal to): True
# a > b  (Greater than): True
# a < b  (Less than): False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = 10 
b = 20 

if a>10 and b>20:
    print("Both a and b are greater than 10 and 20")
else:
    print("Both a and b are not greater than 10 and 20")
    
if a==10 or b==30:
    print("Either a is 10 or b is 30")

if not(a==10 and b==30):
    print("Not both a is 10 and b is 30")
# Out:
# Both a and b are not greater than 10 and 20
# Either a is 10 or b is 30
# Not both a is 10 and b is 30

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = float(input("Enter a number: "))

print(num**2)
# Out:
# 100.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = float(input("Enter a number: "))

if num % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
num = float(input("Enter a number: "))

sum = (num*(num+1))/2
print(sum)
# Out:
# 5050.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = float(input("Enter a year: "))

if(year%4==0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
string = input("Enter a string: ")

rev_strings = string[::-1]

print(rev_strings)
# Out:
# hsuyA

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

str = input("Enter a string:")

if (str == str[::-1]):
    print("The string is a palindrome")
else:
    print("The string is not a palindrome")
# Out:
# The string is not a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Create a list of unsorted numbers
original_numbers = [42, 15, 8, 99, 23, 4]

# Use the sorted() function to create a new list
new_sorted_list = sorted(original_numbers)

print("Original List:", original_numbers)
print("Sorted List:  ", new_sorted_list)
# Out:
# Original List: [42, 15, 8, 99, 23, 4]
# Sorted List:   [4, 8, 15, 23, 42, 99]
